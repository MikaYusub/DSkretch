# %%
from Utilities import DrawPlots

# %%
dp = DrawPlots()
dp.draw_plots()
# Out:
#                   name  gt_corners  rb_corners       mean  ...  floor_min  ceiling_mean  ceiling_max  ceiling_min
# 0         Schlafzimmer           4           4   3.956313  ...   0.274574      3.924762     8.501885     0.331494
# 1                Küche           4           4  23.019122  ...   0.724299     44.785141    52.605437    36.880814
# 2             Bathroom           4           4   1.013833  ...   0.301673      1.368528     1.950322     0.878106
# 3         Lounge/Diner           8           8   3.832620  ...   0.173307      4.065157    18.236935     0.253457
# 4           Essbereich           4           4   8.017758  ...   0.762948      8.216069    15.642853     0.909029
# ...                ...         ...         ...        ...  ...        ...           ...          ...          ...
# 1342    Master Bedroom           4           4   1.739907  ...   0.166677      2.992362     4.703960     1.216172
# ...
