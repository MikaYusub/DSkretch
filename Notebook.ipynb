# %%
from Utilities import DrawPlots

# %%
dp = DrawPlots(json = 'https://ai-process-sandy.s3.eu-west-1.amazonaws.com/purge/deviation.json')
dp.draw_plots()
# Out:
# ['plots\\Comparing_ceiling_max_and_floor_max.jpg',
#  'plots\\Confusion_matrix.jpg',
#  'plots\\Correlation_between_columns.jpg']
